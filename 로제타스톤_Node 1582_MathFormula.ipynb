# %% [markdown]
# # Math Formula

# %% [raw]
# <배울 내용>
#
# (1)
# df['새로운컬럼'] = df['기존컬럼1'] 연산자 df['기존컬럼2']
# df['기존컬럼'] = df['기존컬럼1'] 연산자 df['기존컬럼2']
#
# (2) 통계정보 얻는 방법
#
# df['컬럼명'].describe()

# %%
# 임포트 판다스

import pandas as pd
from pandas import DataFrame, Series

# %% [markdown]
# ## 엑셀파일 불러오기

# %%
df = pd.read_excel('Documents2.xlsx')

# %%
df.head(3)
# Out:
#    번호 연구분야대분류 연구분야중분류  기준년도       사업부처 연구개발단계 사업화형태 연구수행주체     정부투자연구비합계  \
# 0   1      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN     기타  1.010000e+08
# 1   2      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN     대학  4.761042e+09
# 2   3      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN  출연연구소  6.961235e+10
#
#    지원과제수  사업화성과건수합계  고용창출인원합계  당해년도매출액합계
# 0      1          0       0.0        0.0
# 1     27          0       0.0        0.0
# 2     30          0       0.0        0.0

# %% [markdown]
# ## 컬럼 베이스 계산

# %%
# (ex) df['번호'] = df['기준년도'] * df['지원과제수']

# %%
df.head(3)
# Out:
#       번호 연구분야대분류 연구분야중분류  기준년도       사업부처 연구개발단계 사업화형태 연구수행주체     정부투자연구비합계  \
# 0   2013      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN     기타  1.010000e+08
# 1  54351      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN     대학  4.761042e+09
# 2  60390      EA    EA01  2013  과학기술정보통신부  1기초연구   NaN  출연연구소  6.961235e+10
#
#    지원과제수  사업화성과건수합계  고용창출인원합계  당해년도매출액합계  new  new2
# 0      1          0       0.0        0.0    1   0.0
# 1     27          0       0.0        0.0    1   0.0
# 2     30          0       0.0        0.0    1   0.0

# %%
df['당해년도매출액합계'].describe()
# Out:
# count    5.692500e+04
# mean     7.861144e+08
# std      2.301652e+10
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.065696e+12
# Name: 당해년도매출액합계, dtype: float64

# %%
df[df['new2']>0]
# Out:
#           번호 연구분야대분류 연구분야중분류  기준년도       사업부처 연구개발단계                   사업화형태  \
# 18        19      EA    EA01  2013      방위사업청    4기타           기술이전_기존업체-상품화
# 21        22      EA    EA01  2013    산업통상자원부  2개발연구  기술보유자의 직접사업화_기존업체-공정개선
# 22        23      EA    EA01  2013    산업통상자원부  2개발연구   기술보유자의 직접사업화_기존업체-상품화
# 25        26      EA    EA01  2013    산업통상자원부  3응용연구   기술보유자의 직접사업화_기존업체-상품화
# 33        34      EA    EA01  2013    중소벤처기업부  2개발연구  기술보유자의 직접사업화_기존업체-공정개선
# ...      ...     ...     ...   ...        ...    ...                     ...
# 56884  56885      ZZ      ZZ  2013    산업통상자원부  2개발연구                 기술이전_창업
# 56894  56895      ZZ      ZZ  2015  과학기술정보통신부    4기타         기술보유자의 직접사업화_창업
# 56895  56896      ZZ      ZZ  2015  과학기술정보통신부    4기타          기술이전_기존업체-공정개선
# 56896  56897      ZZ      ZZ  2015  과학기술정보통신부    4기타           기술이전_기존업체-상품화
# 56897  56898      ZZ      ZZ  2015  과학기술정보통신부    4기타                 기술이전_창업
#
# ...

# %%
df['new2'].describe()
# Out:
# count    56868.0
# mean         inf
# std          NaN
# min          0.0
# 25%          0.0
# 50%          0.0
# 75%          0.0
# max          inf
# Name: new2, dtype: float64

# %%
# %matplotlib inline
df['new2'].plot()
